# %% [markdown]
# # Import

# %%
import pandas
from sklearn.ensemble import GradientBoostingClassifier
import yandex_evaluation as evaluation

# %% [markdown]
# # Read training data

# %%
folder = 'input/'
train = pandas.read_csv(folder + 'training.csv', index_col='id')

# %%
train.head().T
# Out:
# id                       18453471      5364094       11130990      15173787  \
# LifeTime                 0.001578      0.000988      0.000877      0.000854
# dira                     0.999999      0.999705      0.999984      0.999903
# FlightDistance          14.033335      5.536157      6.117302      5.228067
# FlightDistanceError      0.681401      0.302341      0.276463      0.220739
# IP                       0.016039      0.142163      0.034746      0.076389
# IPSig                    0.451886      9.564503      1.970751      4.271331
# VertexChi2               1.900433      0.865666     10.975849      3.276358
# pt                    1482.037476   3050.720703   3895.908691   4010.781738
# DOCAone                  0.066667      0.024022      0.055044      0.053779
# DOCAtwo                  0.060602      0.019245      0.047947      0.006417
# DOCAthree                0.083660      0.030784      0.096829      0.044816
# IP_p0p2                  0.208855      0.336345      0.169165      0.050989
# IP_p1p2                  0.074343      0.173161      0.079789      0.068167
# isolationa               8.000000      7.000000      1.000000      2.000000
# isolationb               5.000000     12.000000      0.000000      2.000000
# isolationc               7.000000      2.000000      1.000000      4.000000
# isolationd               1.000000      0.000000      0.000000      0.000000
# isolatione               0.000000      1.000000      0.000000      0.000000
# isolationf               3.000000      1.000000      0.000000      0.000000
# iso                      4.000000      2.000000      0.000000      0.000000
# CDF1                     0.473952      0.325785      1.000000      1.000000
# CDF2                     0.349447      0.265939      0.786482      0.501195
# CDF3                     0.329157      0.192599      0.557760      0.501195
# ISO_SumBDT              -0.579324     -0.873926     -0.479636     -0.439453
# p0_IsoBDT               -0.256309     -0.223774     -0.202451     -0.162267
# p1_IsoBDT               -0.215444     -0.224871     -0.100762     -0.176424
# p2_IsoBDT               -0.107570     -0.425281     -0.176424     -0.100762
# p0_track_Chi2Dof         1.921700      0.958776      0.720973      1.172767
# p1_track_Chi2Dof         0.866657      0.858357      1.408519      2.044164
# p2_track_Chi2Dof         1.230708      1.810709      1.038347      0.811454
# p0_IP                    0.988054      0.098752      0.186143      0.255752
# p1_IP                    0.601483      0.219099      0.215668      0.210698
# p2_IP                    0.277090      0.614524      0.371820      0.392195
# p0_IPSig                16.243183      3.610463      4.851371      7.292110
# p1_IPSig                 4.580875     15.555593     11.590331      8.778173
# p2_IPSig                 5.939936     11.238523     13.723293     16.462036
# p0_pt                  353.819733    656.524902    658.523743   1047.216187
# p1_pt                  448.369446   2033.918701   2576.380615   1351.734131
# p2_pt                 1393.246826    747.137024    963.652466   1685.003662
# p0_p                  3842.096436   8299.368164  11323.134766  11502.081055
# p1_p                 12290.760742  16562.667969  22695.388672  16909.515625
# p2_p                 39264.398438   7341.257812  10225.309570   9141.426758
# p0_eta                   3.076006      3.228553      3.536903      3.087461
# p1_eta                   4.003800      2.786543      2.865686      3.218034
# p2_eta                   4.031514      2.975564      3.052810      2.375592
# SPDhits                458.000000    406.000000    196.000000    137.000000
# production             -99.000000    -99.000000    -99.000000    -99.000000
# signal                   0.000000      0.000000      0.000000      0.000000
# mass                  1866.300049   1727.095947   1898.588013   1840.410034
# min_ANNmuon              0.277559      0.225924      0.368630      0.246045
#
# id                       1102544
# LifeTime                 0.001129
# dira                     0.999995
# FlightDistance          39.069534
# FlightDistanceError      1.898197
# IP                       0.120936
# IPSig                    4.984982
# VertexChi2               0.468348
# pt                    4144.546875
# DOCAone                  0.004491
# DOCAtwo                  0.037326
# DOCAthree                0.019026
# IP_p0p2                  0.172065
# IP_p1p2                  0.131732
# isolationa               0.000000
# isolationb               2.000000
# isolationc               0.000000
# isolationd               0.000000
# isolatione               0.000000
# isolationf               0.000000
# iso                      0.000000
# CDF1                     1.000000
# CDF2                     1.000000
# CDF3                     0.639926
# ISO_SumBDT              -0.822285
# p0_IsoBDT               -0.291524
# p1_IsoBDT               -0.261078
# p2_IsoBDT               -0.269682
# p0_track_Chi2Dof         1.523252
# p1_track_Chi2Dof         0.435325
# p2_track_Chi2Dof         0.581312
# p0_IP                    0.270755
# p1_IP                    0.183355
# p2_IP                    0.630763
# p0_IPSig                 6.783962
# p1_IPSig                 3.342091
# p2_IPSig                17.252840
# p0_pt                 1442.538208
# p1_pt                 1755.792236
# p2_pt                 1282.428711
# p0_p                 74117.117188
# p1_p                 97612.804688
# p2_p                 47118.785156
# p0_eta                   4.632295
# p1_eta                   4.711155
# p2_eta                   4.296878
# SPDhits                477.000000
# production             -99.000000
# signal                   0.000000
# mass                  1899.793945
# min_ANNmuon              0.222060

# %% [markdown]
# # Define training features
# Here we use subset of the all features to pass the agreement checking

# %%
#variables = ['LifeTime', 'FlightDistance', 'pt']
variables = train.columns[:-10]
variables
# Out:
# Index([u'LifeTime', u'dira', u'FlightDistance', u'FlightDistanceError', u'IP',
#        u'IPSig', u'VertexChi2', u'pt', u'DOCAone', u'DOCAtwo', u'DOCAthree',
#        u'IP_p0p2', u'IP_p1p2', u'isolationa', u'isolationb', u'isolationc',
#        u'isolationd', u'isolatione', u'isolationf', u'iso', u'CDF1', u'CDF2',
#        u'CDF3', u'ISO_SumBDT', u'p0_IsoBDT', u'p1_IsoBDT', u'p2_IsoBDT',
#        u'p0_track_Chi2Dof', u'p1_track_Chi2Dof', u'p2_track_Chi2Dof', u'p0_IP',
#        u'p1_IP', u'p2_IP', u'p0_IPSig', u'p1_IPSig', u'p2_IPSig', u'p0_pt',
#        u'p1_pt', u'p2_pt', u'p0_p'],
#       dtype='object')

# %% [markdown]
# # Baseline training

# %%
baseline = GradientBoostingClassifier(n_estimators=40, learning_rate=0.01, subsample=0.7,
                                      min_samples_leaf=10, max_depth=7, random_state=11)
baseline.fit(train[variables], train['signal'])
# Out:
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=7, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=10, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=40,
#               random_state=11, subsample=0.7, verbose=0, warm_start=False)

# %% [markdown]
# # Check agreement test

# %%
check_agreement = pandas.read_csv(folder + 'check_agreement.csv', index_col='id')
agreement_probs = baseline.predict_proba(check_agreement[variables])[:, 1]

ks = evaluation.compute_ks(
    agreement_probs[check_agreement['signal'].values == 0],
    agreement_probs[check_agreement['signal'].values == 1],
    check_agreement[check_agreement['signal'] == 0]['weight'].values,
    check_agreement[check_agreement['signal'] == 1]['weight'].values)
print 'KS metric', ks, ks < 0.09
# Out:
# KS metric 0.059192038363 True

# %% [markdown]
# # Check correlation test

# %%
check_correlation = pandas.read_csv(folder + 'check_correlation.csv', index_col='id')
correlation_probs = baseline.predict_proba(check_correlation[variables])[:, 1]
cvm = evaluation.compute_cvm(correlation_probs, check_correlation['mass'])
print 'CvM metric', cvm, cvm < 0.002
# Out:
# CvM metric 0.000970051229354 True

# %% [markdown]
# # Compute weighted AUC on the training data with min_ANNmuon > 0.4

# %%
train_eval = train[train['min_ANNmuon'] > 0.4]
train_probs = baseline.predict_proba(train_eval[variables])[:, 1]
AUC = evaluation.roc_auc_truncated(train_eval['signal'], train_probs)
print 'AUC', AUC
# Out:
# AUC 0.977884355139

# %% [markdown]
# # Predict test, create file for kaggle

# %%
test = pandas.read_csv(folder + 'test.csv', index_col='id')
result = pandas.DataFrame({'id': test.index})
result['prediction'] = baseline.predict_proba(test[variables])[:, 1]

# %%
result.to_csv('output/baseline.csv', index=False, sep=',')
